# %%
import time
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
# %matplotlib inline

# %% [markdown]
# # Data Loading
# We first define a function for downloading and loading MNIST.

# %%
mnist = input_data.read_data_sets(train_dir = "./MNIST_data", one_hot=True)
# Out:
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Extracting
#  ./MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting
#  ./MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Implementation of an Autoencoder

# %%
def predict(x):
    """predict returns prediction given input
    """
    x = tf.reshape(x, [-1, 28, 28, 1])
    conv1 = tf.layers.conv2d(x, filters=8, kernel_size=(3,3), strides=(1,1), padding='SAME', use_bias=True)
    maxpool1 = tf.layers.max_pooling2d(conv1, pool_size=(2,2), strides=(2,2), padding='SAME')
    
    conv2 = tf.layers.conv2d(maxpool1, filters=4, kernel_size=(3,3), strides=(1,1), padding='SAME', use_bias=True)
    maxpool2 = tf.layers.max_pooling2d(conv2, pool_size=(2,2), strides=(2,2), padding='SAME')
    
    conv3 = tf.layers.conv2d(maxpool2, filters=2, kernel_size=(3,3), strides=(1,1), padding='SAME', use_bias=True)
    conv2d_transpose1 = tf.layers.conv2d_transpose(conv3, filters=4, kernel_size=(2, 2), padding='same', strides=(2,2))

    conv4 = tf.layers.conv2d(conv2d_transpose1, filters=4, kernel_size=(3,3), strides=(1,1), padding='SAME', use_bias=True)
    conv2d_transpose2 = tf.layers.conv2d_transpose(conv4, filters=8, kernel_size=(2, 2), padding='same', strides=(2,2))
    
    conv5 = tf.layers.conv2d(conv2d_transpose2, filters=8, kernel_size=(3,3), strides=(1,1), padding='SAME', use_bias=True)
    output_conv = tf.layers.conv2d_transpose(conv5, filters=1, kernel_size=(1, 1), padding='same', strides=(1,1))
    
    output = tf.reshape(output_conv, [tf.shape(output_conv)[0], 784])
    return output

    
def train(learning_rate=0.001, max_epochs=10, 
              batch_size=64):
        """ Train network on the given data. """
        
        # Define placeholder for x
        x = tf.placeholder(tf.float32, [None, 784])

        # Predict given the data
        y_conv = predict(x)
        
        #loss
        loss = tf.reduce_mean(tf.square(y_conv - x))
    
        # Define loss and optimizer
        train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)
        
        loss_list = list()
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            for epoch in range(max_epochs):
                total_loss = 0.0
                for _ in range(int(mnist.train.num_examples/batch_size)):
                    batch_xs, batch_ys = mnist.train.next_batch(batch_size)
                    _, batch_loss = sess.run([train_step, loss],feed_dict={x: batch_xs})
                    #loss_list.append(batch_loss)
                    #total_loss += batch_loss
                loss_list.append(batch_loss)

                # Testing
            # Encode and decode images from test set and visualize their reconstruction.
            n=4
            canvas_orig = np.empty((28 * n, 28 * n))
            canvas_recon = np.empty((28 * n, 28 * n))
            for i in range(n):
                # MNIST test set
                batch_x, _ = mnist.test.next_batch(n)
                # Encode and decode the digit image
                g = sess.run(y_conv, feed_dict={x: batch_x})

                # Display original images
                for j in range(n):
                    # Draw the original digits
                    canvas_orig[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = \
                        batch_x[j].reshape([28, 28])
                # Display reconstructed images
                for j in range(n):
                    # Draw the reconstructed digits
                    canvas_recon[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = \
                        g[j].reshape([28, 28])

        return loss_list, canvas_orig, canvas_recon

# %% [markdown]
# # Task 2: Training of an Autoencoder

# %%
learning_rates = [0.1, 0.01, 0.001]
loss_learning = list()
plot_data_learning = dict()
for lr in learning_rates:
    l, canvas_orig, canvas_recon = train(learning_rate=lr)
    loss_learning.append(l)
    
    print('Training for learning rate:%s completed' % lr)
    plot_data_learning[lr] = (canvas_orig, canvas_recon)
# Out:
# Training for learning rate:0.1 completed
# Training for learning rate:0.01 completed
# Training for learning rate:0.001 completed

# %% [markdown]
# #Learning curves

# %%
for lr, va in zip(learning_rates, loss_learning):
    plt.plot(range(1,len(va)+1), va, label='Learning rate:%s' % lr)
    plt.xlabel('number of epochs')
    plt.ylabel('loss')
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.savefig('learning_curves.png')
plt.show()

# %% [markdown]
# # Task 3: Plots of Test Images

# %%
n=4
print("Original Images")
plt.figure(figsize=(n, n))
plt.imshow(canvas_orig, origin="upper", cmap="gray")
plt.savefig('original.png')
plt.show()
for lr, plots in plot_data_learning.items():
    print("Learning Rate: %s" % lr)    
    

    print("Reconstructed Images")
    plt.figure(figsize=(n, n))
    plt.imshow(plots[1], origin="upper", cmap="gray")
    plt.savefig('lr_%s.png' % lr)
    plt.show()
# Out:
# Original Images
# Learning Rate: 0.1
# Reconstructed Images
# Learning Rate: 0.01
# Reconstructed Images
# Learning Rate: 0.001
# Reconstructed Images
